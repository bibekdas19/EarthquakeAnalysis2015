# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
os.getcwd()
# Out:
# 'D:\\data science with python\\jupyter notebook'

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'Champions.xlsx',
#  'Disaster data',
#  'Earthquake1.csv',
#  'Earthquake2015.csv',
#  'Earthquake2019.csv',
#  'Earthquake2020.csv',
#  'example.json',
#  'excel file.ipynb',
#  'Food Demand Forecasting.ipynb',
#  'fulfilment_center_info.csv',
#  'Heros.xlsx',
#  'meal_info.csv',
#  'Natural Language Processing.ipynb',
#  'notebook',
#  'numpy_detail.ipynb',
#  'numpy_detail_class_27Aug.ipynb',
#  'project1.csv',
#  'project1.ipynb',
#  'Scraping_Seismonepal_Class_File.ipynb',
#  'solution.csv.csv',
#  'solution1.csv.csv',
#  'solution2.csv.csv',
#  'submission1.csv',
#  'submission_food.csv',
#  'task7.py',
#  'test.csv',
#  'test_data.csv',
#  'test_food.csv',
#  'train.csv',
#  'train_data.csv',
#  'train_loan.csv',
#  'untitled',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
# ...

# %%
earthquake2015=pd.read_csv('Earthquake2015.csv',index_col='Date',parse_dates=['Date'])

# %%
print(earthquake2015.head())
# Out:
#             Time  Latitude  Longitude  Magnitude       Epicenter
# Date
# 2072-9-16  07:41     27.86      85.72        4.3  Sindhupalchowk
# 2072-9-14  03:52     27.70      86.12        4.2         Dolakha
# 2072-9-12  10:33     29.35      81.29        4.1          Bajura
# 2072-9-8   08:59     27.79      86.08        4.1         Dolakha
# 2072-9-3   04:01     29.44      81.69        5.5          Bajura

# %%
print(earthquake2015['Epicenter'].value_counts())
# Out:
# Dolakha            144
# Sindhupalchowk      87
# Nuwakot             34
# Gorkha              31
# Rasuwa              27
# Dhading             25
# Sindhupalchok       17
# Kathmandu           16
# Sindupalchok        12
# Tibet                9
# Ramechhap            4
# Humla                4
# Lalitpur             4
# Kavre                4
# Kavrepalanchowk      3
# Bajura               3
# Kaski                2
# Baglung              2
# Jajarkot             2
# Darchula             2
# kavrepalanchok       1
# Udayapur             1
# Dailekh              1
# kavre                1
# Lamjung              1
# Doti                 1
# Sindupalchowk        1
# Myagdi               1
# Kavrepalanchok       1
# Kabre                1
# Lalitput             1
# Rukum                1
# Panchthar            1
# Bhojpur              1
# Name: Epicenter, dtype: int64

# %%
No_of_epicenters=earthquake2015['Epicenter'].value_counts()
No_of_epicenters.plot(kind='pie',figsize=(5,5),title='Epicenter Dominance')
# Out:
# <AxesSubplot:title={'center':'Epicenter Dominance'}, ylabel='Epicenter'>

# %%
No_of_epicenters.plot(kind='bar', rot = 90,figsize=(11,5),title='Epicenters')
# Out:
# <AxesSubplot:title={'center':'Epicenters'}>

# %%
print(earthquake2015[['Date','Epicenter']]('Magnitude').agg(max))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-a5bc758ef715> in <module>
# ----> 1 print(earthquake2015[['Date','Epicenter']]('Magnitude').agg(max))
#
# c:\users\jk\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2903             if is_iterator(key):
#    2904                 key = list(key)
# -> 2905             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2906
#    2907         # take() does not accept boolean indexers
#
# c:\users\jk\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
print(earthquake2015['Magnitude'].agg(min))
# Out:
# 4.0
